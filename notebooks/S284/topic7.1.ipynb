# %%
import pandas as pd
import numpy as np

import sys
import math

sys.path.append('../..')
import astroutils as astro

# %% [markdown]
# #### Question 1.1
#
# Galaxy NGC 7318a is observed to have a redshift  0.022.
#
# Calculate the distance to the galaxy and hence state how long ago the light from the galaxy was emitted.
#
# (You may assume a Hubble constant of 70 km s−1 Mpc−1.)

# %%
astro.light_travel_time_from_redshift(
    redshift=0.020,
    sf=3
)
# Out:
# '2.79e+08'
